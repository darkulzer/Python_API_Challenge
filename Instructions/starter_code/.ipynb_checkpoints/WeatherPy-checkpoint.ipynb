# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#import openweathermapy as ow
from pprint import pprint
import datetime
# Import API key
from api_keys import weather_api_key as api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ## Perform API Calls

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 2 of set 0 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 3 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 4 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 5 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 6 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 7 of set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 8 of set 0 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 9 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 10 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 11 of set 0 | shagonar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 12 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 13 of set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 14 of set 0 | south sioux city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 15 of set 0 | mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 16 of set 0 | villanueva de la serena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 17 of set 0 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 18 of set 0 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 19 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 20 of set 0 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 21 of set 0 | fort-de-france
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 22 of set 0 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 23 of set 0 | kyabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 24 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 25 of set 0 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 26 of set 0 | nybro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 27 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 28 of set 0 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 29 of set 0 | leopold
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 30 of set 0 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 31 of set 0 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 32 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 33 of set 0 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 34 of set 0 | batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 35 of set 0 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 36 of set 0 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 37 of set 0 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 38 of set 0 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 39 of set 0 | arcata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 40 of set 0 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 41 of set 0 | roros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 42 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 43 of set 0 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 44 of set 0 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 45 of set 0 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 46 of set 0 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 47 of set 0 | novovoronezh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 48 of set 0 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 49 of set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 50 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 0 of set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 1 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 2 of set 1 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 3 of set 1 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 4 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 5 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 6 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 7 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 8 of set 1 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 9 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 10 of set 1 | erikoussa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 11 of set 1 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 12 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 13 of set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 14 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 15 of set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 16 of set 1 | qarqin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 17 of set 1 | puerto varas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 18 of set 1 | bom jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 19 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 20 of set 1 | cobourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 21 of set 1 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 22 of set 1 | hurghada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 23 of set 1 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 24 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 25 of set 1 | garmsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 26 of set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 27 of set 1 | yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 28 of set 1 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 29 of set 1 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 30 of set 1 | santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 31 of set 1 | macusani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 32 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 33 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 34 of set 1 | sussex
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 35 of set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 36 of set 1 | shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 37 of set 1 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 38 of set 1 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 39 of set 1 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 40 of set 1 | douglas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 41 of set 1 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 42 of set 1 | troyes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 43 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 44 of set 1 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 45 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 46 of set 1 | bat khela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 47 of set 1 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 48 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 49 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 50 of set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 0 of set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 1 of set 2 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 2 of set 2 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 3 of set 2 | itamaraca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 4 of set 2 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 5 of set 2 | seekirchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 6 of set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 7 of set 2 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 8 of set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 9 of set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 10 of set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 11 of set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 12 of set 2 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 13 of set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 14 of set 2 | touho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 15 of set 2 | bongandanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 16 of set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 17 of set 2 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 18 of set 2 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 19 of set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 20 of set 2 | nazareno etla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 21 of set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 22 of set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 23 of set 2 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 24 of set 2 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 25 of set 2 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 26 of set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 27 of set 2 | takefu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 28 of set 2 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 29 of set 2 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 30 of set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 31 of set 2 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 32 of set 2 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 33 of set 2 | scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 34 of set 2 | bahia blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 35 of set 2 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 36 of set 2 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 37 of set 2 | angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 38 of set 2 | vieques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 39 of set 2 | kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 40 of set 2 | jieshou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 41 of set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 42 of set 2 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 43 of set 2 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 44 of set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 45 of set 2 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 46 of set 2 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 47 of set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 48 of set 2 | saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 49 of set 2 | jabiru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 50 of set 2 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 0 of set 3 | tallya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 1 of set 3 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 2 of set 3 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 3 of set 3 | staryy nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 4 of set 3 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 5 of set 3 | igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 6 of set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 7 of set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 8 of set 3 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 9 of set 3 | sinjah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 10 of set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 11 of set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 12 of set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 13 of set 3 | kaspiysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 14 of set 3 | zholymbet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 15 of set 3 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 16 of set 3 | linchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 17 of set 3 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# City not found!
# Processing record 18 of set 3 | nerchinskiy zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 19 of set 3 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 20 of set 3 | souris
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 21 of set 3 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 22 of set 3 | jutai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 23 of set 3 | rumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 24 of set 3 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 25 of set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 26 of set 3 | zabol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 27 of set 3 | asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 28 of set 3 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 29 of set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 30 of set 3 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3
# Processing record 31 of set 3 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a2938ae3a35b1b0ff42125eae31d15a3

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()

# %%
weather_data.head()

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'output_data', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# Analysis: The temperature rises between -40 to 20 degrees Latitude , and then begins to fall from 20 to 80 degrees Latitude.

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")

# %% [markdown]
# Analysis: There is no correlation between Humidity and Latitude.

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %% [markdown]
# Analysis: There is no correlation between Latitude and Cloudiness.

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")

# %% [markdown]
# Analysis: There is no correlation between Latitude and Wind Speed.
